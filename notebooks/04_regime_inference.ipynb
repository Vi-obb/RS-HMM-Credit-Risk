# %% [markdown]
# # Regime Inference
#
# Fit the two-state HMM and inspect the inferred stress probabilities.

# %%
from pathlib import Path
import pandas as pd
from rs_hmm.workflow import run_hmm_fit

CONFIG = Path('configs/sim_v1.yml')
output = run_hmm_fit(CONFIG)
output

# %%
macro_hmm = pd.read_csv(output)
macro_hmm[['month', 'regime_true', 'p_stress', 'hard_stress']].head()
