# %% [markdown]
# # Baseline Modeling
#
# Train the baseline and macro-augmented logistic models through the shared training workflow.

# %%
from pathlib import Path
import pandas as pd
from rs_hmm.workflow import run_model_training

CONFIG = Path('configs/sim_v1.yml')
outputs = run_model_training(CONFIG)
outputs

# %%
preds = pd.read_csv(outputs['predictions'])
preds[preds['model'].isin(['baseline', 'macro'])].head()
