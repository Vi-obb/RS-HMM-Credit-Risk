# %% [markdown]
# # Label Audit
#
# Build forward default labels and confirm the target structure.

# %%
from pathlib import Path
import pandas as pd
from rs_hmm.workflow import run_build_labels

CONFIG = Path('configs/sim_v1.yml')
output = run_build_labels(CONFIG)
output

# %%
labeled = pd.read_csv(output)
labeled[['loan_id', 'month', 'y_6m']].head()
