# %% [markdown]
# # Simulation Sanity Check
#
# Run the synthetic data generator from the shared config and inspect the main outputs.

# %%
from pathlib import Path
import pandas as pd
from rs_hmm.workflow import run_simulation

CONFIG = Path('configs/sim_v1.yml')
outputs = run_simulation(CONFIG)
outputs

# %%
panel = pd.read_csv(outputs['panel'])
panel.head()
