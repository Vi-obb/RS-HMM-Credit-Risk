# %% [markdown]
# # Regime-Aware Comparison
#
# Run the evaluation stage and compare the saved metrics tables.

# %%
from pathlib import Path
import pandas as pd
from rs_hmm.workflow import run_evaluation

CONFIG = Path('configs/sim_v1.yml')
outputs = run_evaluation(CONFIG)
outputs

# %%
metrics = pd.read_csv(outputs['metrics'])
metrics
