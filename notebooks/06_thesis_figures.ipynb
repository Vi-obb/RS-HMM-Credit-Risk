# %% [markdown]
# # Thesis Figures
#
# Collect the saved figures and tables that feed directly into the manuscript and slides.

# %%
from pathlib import Path
import pandas as pd

FIG_DIR = Path('reports/figures')
TABLE_DIR = Path('reports/tables')
sorted(path.name for path in FIG_DIR.glob('*'))

# %%
metrics = pd.read_csv(TABLE_DIR / 'model_metrics.csv')
metrics.sort_values(['split', 'brier']).head()
